# %% [markdown]
# ## ✦ Initializing...

# %%
from IPython.display import HTML, display

display(HTML("""
<style>
  @import url('https://fonts.googleapis.com/css2?family=Playfair+Display:ital,wght@0,400;0,700;1,400;1,700&family=Cormorant+Garamond:ital,wght@0,300;0,400;1,300;1,400&family=EB+Garamond:ital@0;1&display=swap');

  :root {
    --rose: #e8a0a8;
    --rose-light: #f5d0d6;
    --rose-dark: #c2596a;
    --gold: #d4a96a;
    --cream: #fdf6ee;
    --ink: #1a1015;
    --ink-soft: #3d2535;
    --bg-dark: #0e0811;
    --bg-mid: #16101e;
  }

  /* ── Full notebook background ── */
  body, .jp-Notebook, #notebook {
    background: var(--bg-dark) !important;
    font-family: 'Cormorant Garamond', serif !important;
  }
  .jp-Cell, .cell {
    background: transparent !important;
    border: none !important;
  }

  /* ── Stars canvas (behind everything) ── */
  #nasha-stars-canvas {
    position: fixed;
    top: 0; left: 0;
    width: 100vw; height: 100vh;
    pointer-events: none;
    z-index: 0;
    opacity: 0.6;
  }

  /* ── Main wrapper ── */
  #nasha-main {
    position: relative;
    z-index: 1;
    max-width: 820px;
    margin: 0 auto;
    padding: 0 20px 80px;
  }

  /* ── Hero section ── */
  #nasha-hero {
    text-align: center;
    padding: 80px 20px 60px;
    position: relative;
  }
  #nasha-hero::before {
    content: '';
    position: absolute;
    top: 50%; left: 50%;
    transform: translate(-50%, -50%);
    width: 500px; height: 500px;
    background: radial-gradient(ellipse, rgba(200, 80, 110, 0.18) 0%, transparent 70%);
    pointer-events: none;
    border-radius: 50%;
    animation: pulseGlow 5s ease-in-out infinite;
  }
  @keyframes pulseGlow {
    0%, 100% { opacity: 0.6; transform: translate(-50%,-50%) scale(1); }
    50%       { opacity: 1;   transform: translate(-50%,-50%) scale(1.15); }
  }

  .hero-label {
    font-family: 'Cormorant Garamond', serif;
    font-size: 0.85rem;
    letter-spacing: 0.35em;
    text-transform: uppercase;
    color: var(--rose);
    opacity: 0.75;
    margin-bottom: 18px;
    display: block;
    animation: fadeUp 1s ease both;
  }

  .hero-name {
    font-family: 'Playfair Display', serif;
    font-size: clamp(2.8rem, 7vw, 5.2rem);
    font-weight: 700;
    font-style: italic;
    line-height: 1.1;
    background: linear-gradient(135deg, #f5d0d6 0%, #e8a0a8 40%, #d4a96a 100%);
    -webkit-background-clip: text;
    -webkit-text-fill-color: transparent;
    background-clip: text;
    filter: drop-shadow(0 0 30px rgba(232,160,168,0.5));
    animation: fadeUp 1.2s ease 0.2s both;
  }

  .hero-name .name-highlight {
    display: block;
  }

  .divider-ornament {
    display: flex;
    align-items: center;
    justify-content: center;
    gap: 14px;
    margin: 28px auto;
    animation: fadeUp 1.4s ease 0.4s both;
  }
  .divider-ornament::before,
  .divider-ornament::after {
    content: '';
    flex: 1;
    max-width: 140px;
    height: 1px;
    background: linear-gradient(to right, transparent, var(--rose), transparent);
    opacity: 0.6;
  }
  .divider-ornament span {
    color: var(--rose);
    font-size: 1.1rem;
    opacity: 0.8;
  }

  .hero-sub {
    font-family: 'EB Garamond', serif;
    font-style: italic;
    font-size: 1.05rem;
    color: rgba(245, 208, 214, 0.6);
    letter-spacing: 0.05em;
    animation: fadeUp 1.6s ease 0.6s both;
  }

  /* ── Letter card ── */
  #nasha-letter {
    background: linear-gradient(160deg, rgba(255,255,255,0.04) 0%, rgba(200,80,110,0.04) 100%);
    border: 1px solid rgba(232,160,168,0.15);
    border-radius: 24px;
    padding: 56px 64px;
    box-shadow:
      0 0 60px rgba(200,80,110,0.08),
      0 0 120px rgba(200,80,110,0.04),
      inset 0 1px 0 rgba(255,255,255,0.08);
    backdrop-filter: blur(12px);
    position: relative;
    overflow: hidden;
    animation: fadeUp 2s ease 0.8s both;
  }
  #nasha-letter::before {
    content: '"';
    position: absolute;
    top: 20px; left: 36px;
    font-family: 'Playfair Display', serif;
    font-size: 9rem;
    line-height: 1;
    color: var(--rose);
    opacity: 0.06;
    pointer-events: none;
    user-select: none;
  }
  #nasha-letter::after {
    content: '';
    position: absolute;
    bottom: -60px; right: -60px;
    width: 200px; height: 200px;
    background: radial-gradient(circle, rgba(212,169,106,0.12) 0%, transparent 70%);
    pointer-events: none;
    border-radius: 50%;
  }

  /* ── Salutation ── */
  .letter-salutation {
    font-family: 'Playfair Display', serif;
    font-style: italic;
    font-size: 1.6rem;
    color: var(--rose-light);
    margin-bottom: 36px;
    filter: drop-shadow(0 0 10px rgba(232,160,168,0.4));
  }

  /* ── Body paragraphs ── */
  .letter-body {
    font-family: 'EB Garamond', serif;
    font-size: 1.18rem;
    line-height: 2;
    color: rgba(245, 208, 214, 0.82);
  }
  .letter-body p {
    margin: 0 0 1.5em;
    text-align: justify;
    text-indent: 1.8em;
  }
  .letter-body p.no-indent {
    text-indent: 0;
  }
  .letter-body p.center-text {
    text-align: center;
    text-indent: 0;
    font-style: italic;
    color: rgba(232,160,168,0.9);
  }

  /* ── Highlight name ── */
  .name-inline {
    font-family: 'Playfair Display', serif;
    font-style: italic;
    font-weight: 700;
    background: linear-gradient(135deg, var(--rose-light), var(--gold));
    -webkit-background-clip: text;
    -webkit-text-fill-color: transparent;
    background-clip: text;
    filter: drop-shadow(0 0 8px rgba(232,160,168,0.5));
  }

  /* ── Section break ── */
  .section-break {
    text-align: center;
    color: var(--rose);
    opacity: 0.4;
    font-size: 0.9rem;
    letter-spacing: 0.6em;
    margin: 2em 0;
    user-select: none;
  }

  /* ── Closing ── */
  .letter-closing {
    margin-top: 48px;
    padding-top: 32px;
    border-top: 1px solid rgba(232,160,168,0.12);
    text-align: right;
  }
  .letter-closing .closing-dash {
    font-family: 'Cormorant Garamond', serif;
    font-size: 1.05rem;
    font-style: italic;
    color: rgba(245, 208, 214, 0.65);
    letter-spacing: 0.02em;
    filter: drop-shadow(0 0 6px rgba(232,160,168,0.2));
  }

  /* ── Footer ── */
  #nasha-footer {
    text-align: center;
    padding: 48px 20px 20px;
    animation: fadeUp 2.2s ease 1.2s both;
  }
  .footer-name {
    font-family: 'Playfair Display', serif;
    font-style: italic;
    font-size: 2rem;
    background: linear-gradient(135deg, var(--rose) 0%, var(--gold) 100%);
    -webkit-background-clip: text;
    -webkit-text-fill-color: transparent;
    background-clip: text;
    filter: drop-shadow(0 0 20px rgba(232,160,168,0.4));
    letter-spacing: 0.04em;
  }
  .footer-meta {
    margin-top: 10px;
    font-family: 'Cormorant Garamond', serif;
    font-size: 0.78rem;
    letter-spacing: 0.3em;
    text-transform: uppercase;
    color: rgba(232,160,168,0.3);
  }

  /* ── Floating hearts ── */
  .floating-hearts {
    pointer-events: none;
    user-select: none;
    position: absolute;
    width: 100%; height: 100%;
    top: 0; left: 0;
    overflow: hidden;
  }
  .fheart {
    position: absolute;
    bottom: -30px;
    font-size: 1rem;
    animation: floatHeart linear infinite;
    opacity: 0;
  }
  @keyframes floatHeart {
    0%   { transform: translateY(0) scale(0.8);   opacity: 0; }
    10%  { opacity: 0.6; }
    90%  { opacity: 0.2; }
    100% { transform: translateY(-120px) scale(1.1); opacity: 0; }
  }

  /* ── Heartbeat line ── */
  #nasha-heartbeat {
    margin: 0 auto 40px;
    max-width: 600px;
    animation: fadeUp 2.4s ease 1.4s both;
  }
  #nasha-heartbeat svg path {
    stroke-dasharray: 900;
    stroke-dashoffset: 900;
    animation: drawLine 3s ease 2s forwards;
  }
  @keyframes drawLine {
    to { stroke-dashoffset: 0; }
  }

  /* ── Poem block ── */
  #nasha-poem {
    background: linear-gradient(135deg, rgba(200,80,110,0.07) 0%, rgba(212,169,106,0.05) 100%);
    border-left: 3px solid var(--rose-dark);
    border-radius: 0 16px 16px 0;
    padding: 32px 40px;
    margin: 48px 0;
    font-family: 'Playfair Display', serif;
    font-style: italic;
    font-size: 1.15rem;
    color: rgba(245,208,214,0.85);
    line-height: 2.1;
    text-align: center;
    animation: fadeUp 2.6s ease 1.6s both;
    filter: drop-shadow(0 0 12px rgba(200,80,110,0.1));
  }
  #nasha-poem .poem-line { display: block; }
  #nasha-poem .poem-gap  { display: block; height: 0.6em; }

  /* ── Animations ── */
  @keyframes fadeUp {
    from { opacity: 0; transform: translateY(30px); }
    to   { opacity: 1; transform: translateY(0); }
  }

  /* ── Responsive ── */
  @media (max-width: 640px) {
    #nasha-letter { padding: 32px 24px; }
    .letter-body  { font-size: 1.05rem; }
  }
</style>

<!-- Stars canvas -->
<canvas id='nasha-stars-canvas'></canvas>

<script>
(function(){
  var canvas = document.getElementById('nasha-stars-canvas');
  if (!canvas) return;
  var ctx = canvas.getContext('2d');
  var stars = [];
  function resize(){
    canvas.width  = window.innerWidth;
    canvas.height = window.innerHeight;
  }
  resize();
  window.addEventListener('resize', resize);
  for(var i=0;i<220;i++){
    stars.push({
      x: Math.random()*canvas.width,
      y: Math.random()*canvas.height,
      r: Math.random()*1.4+0.2,
      a: Math.random(),
      da: (Math.random()-0.5)*0.006,
      dx: (Math.random()-0.5)*0.08,
      dy: (Math.random()-0.5)*0.08
    });
  }
  function draw(){
    ctx.clearRect(0,0,canvas.width,canvas.height);
    stars.forEach(function(s){
      s.a += s.da;
      if(s.a<0||s.a>1) s.da*=-1;
      s.x += s.dx; s.y += s.dy;
      if(s.x<0) s.x=canvas.width;
      if(s.x>canvas.width)  s.x=0;
      if(s.y<0) s.y=canvas.height;
      if(s.y>canvas.height) s.y=0;
      ctx.beginPath();
      ctx.arc(s.x,s.y,s.r,0,Math.PI*2);
      ctx.fillStyle = 'rgba(245,208,214,'+s.a+')';
      ctx.fill();
    });
    requestAnimationFrame(draw);
  }
  draw();
})();
</script>
"""))
print("✦ Styling loaded.")
# Out:
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Playfair+Display:ital,wght@0,400;0,700;1,400;1,700&family=Cormorant+Garamond:ital,wght@0,300;0,400;1,300;1,400&family=EB+Garamond:ital@0;1&display=swap');
#
#   :root {
#     --rose: #e8a0a8;
#     --rose-light: #f5d0d6;
#     --rose-dark: #c2596a;
#     --gold: #d4a96a;
#     --cream: #fdf6ee;
#     --ink: #1a1015;
#     --ink-soft: #3d2535;
#     --bg-dark: #0e0811;
#     --bg-mid: #16101e;
#   }
#
#   /* ── Full notebook background ── */
#   body, .jp-Notebook, #notebook {
#     background: var(--bg-dark) !important;
#     font-family: 'Cormorant Garamond', serif !important;
#   }
#   .jp-Cell, .cell {
#     background: transparent !important;
#     border: none !important;
#   }
#
#   /* ── Stars canvas (behind everything) ── */
#   #nasha-stars-canvas {
#     position: fixed;
#     top: 0; left: 0;
#     width: 100vw; height: 100vh;
#     pointer-events: none;
#     z-index: 0;
#     opacity: 0.6;
#   }
#
# ...

# %%
from IPython.display import HTML, display

display(HTML("""
<div id='nasha-main'>

  <!-- ══ HERO ══════════════════════════════════════ -->
  <div id='nasha-hero'>
    <span class='hero-label'>— sebuah catatan kecil —</span>

    <div class='hero-name'>
      <span class='name-highlight'>Untuk</span>
      <span class='name-highlight'>Nasha Putri Zaqirah</span>
    </div>

    <div class='divider-ornament'>
      <span>✦ &nbsp; ♡ &nbsp; ✦</span>
    </div>

    <p class='hero-sub'>ditulis di antara baris-baris kode, karena kata-kata ini terlalu berharga untuk sekadar dipikirkan.</p>
  </div>

  <!-- ══ HEARTBEAT LINE ════════════════════════════ -->
  <div id='nasha-heartbeat'>
    <svg viewBox='0 0 600 80' fill='none' xmlns='http://www.w3.org/2000/svg'>
      <path
        d='M0 40 L80 40 L110 20 L130 60 L150 10 L170 70 L190 30 L210 40 L340 40 L370 20 L390 55 L405 30 L420 40 L600 40'
        stroke='url(#hbGrad)'
        stroke-width='2'
        stroke-linecap='round'
        stroke-linejoin='round'
      />
      <defs>
        <linearGradient id='hbGrad' x1='0' y1='0' x2='600' y2='0' gradientUnits='userSpaceOnUse'>
          <stop offset='0%'   stop-color='transparent'/>
          <stop offset='30%'  stop-color='#e8a0a8'/>
          <stop offset='60%'  stop-color='#c2596a'/>
          <stop offset='100%' stop-color='transparent'/>
        </linearGradient>
      </defs>
    </svg>
  </div>

"""))
# Out:
# <div id='nasha-main'>
#
#   <!-- ══ HERO ══════════════════════════════════════ -->
#   <div id='nasha-hero'>
#     <span class='hero-label'>— sebuah catatan kecil —</span>
#
#     <div class='hero-name'>
#       <span class='name-highlight'>Untuk</span>
#       <span class='name-highlight'>Nasha Putri Zaqirah</span>
#     </div>
#
#     <div class='divider-ornament'>
#       <span>✦ &nbsp; ♡ &nbsp; ✦</span>
#     </div>
#
#     <p class='hero-sub'>ditulis di antara baris-baris kode, karena kata-kata ini terlalu berharga untuk sekadar dipikirkan.</p>
#   </div>
#
#   <!-- ══ HEARTBEAT LINE ════════════════════════════ -->
#   <div id='nasha-heartbeat'>
#     <svg viewBox='0 0 600 80' fill='none' xmlns='http://www.w3.org/2000/svg'>
#       <path
#         d='M0 40 L80 40 L110 20 L130 60 L150 10 L170 70 L190 30 L210 40 L340 40 L370 20 L390 55 L405 30 L420 40 L600 40'
#         stroke='url(#hbGrad)'
#         stroke-width='2'
#         stroke-linecap='round'
# ...

# %%
from IPython.display import HTML, display

display(HTML("""
  <!-- ══ LETTER ═══════════════════════════════════ -->
  <div id='nasha-letter'>

    <div class='floating-hearts' aria-hidden='true'>
      <span class='fheart' style='left:8%;  animation-duration:8s;  animation-delay:0s;   font-size:0.75rem;'>♡</span>
      <span class='fheart' style='left:22%; animation-duration:11s; animation-delay:2s;   font-size:0.55rem;'>♡</span>
      <span class='fheart' style='left:42%; animation-duration:9s;  animation-delay:4s;   font-size:0.9rem; '>♡</span>
      <span class='fheart' style='left:65%; animation-duration:13s; animation-delay:1.5s; font-size:0.6rem; '>♡</span>
      <span class='fheart' style='left:80%; animation-duration:7s;  animation-delay:3s;   font-size:0.8rem; '>♡</span>
      <span class='fheart' style='left:92%; animation-duration:10s; animation-delay:6s;   font-size:0.5rem; '>♡</span>
    </div>

    <p class='letter-salutation'>Untuk <span class='name-inline'>Nasha Putri Zaqirah</span>,</p>

    <div class='letter-body'>

      <p>Mungkin ini adalah cara yang agak aneh untuk menulis sesuatu tentang seseorang. Bukan di buku harian, bukan di surat kertas yang dilipat rapi, dan bukan juga pesan singkat yang dikirim lewat chat. Aku menulis ini di sebuah file, di dalam notebook yang biasanya dipakai untuk kode, logika, dan perhitungan.</p>

      <p>Namun di antara semua baris kode itu, ada satu bagian yang tidak berisi angka, tidak berisi rumus, tidak berisi algoritma.</p>

      <p class='center-text'>Bagian itu berisi namamu.</p>

      <p class='center-text' style='font-size:1.5rem; font-family: Playfair Display, serif; filter:drop-shadow(0 0 14px rgba(232,160,168,0.5));'>
        <span class='name-inline'>Nasha Putri Zaqirah.</span>
      </p>

      <div class='section-break'>· · · · ·</div>

      <p>Aku tidak tahu apakah suatu hari nanti kamu akan membaca ini atau tidak. Bisa jadi tidak pernah. Bisa jadi file ini hanya akan tersimpan di suatu folder, di dalam komputer, bertahun-tahun lamanya. Tapi aku tetap menuliskannya, karena ada hal-hal yang terkadang lebih baik disimpan dalam tulisan daripada hanya dipikirkan sendirian.</p>

      <p>Aku mengenal banyak orang dalam hidupku, tapi ada beberapa orang yang entah kenapa terasa berbeda. Bukan karena mereka melakukan sesuatu yang besar atau dramatis, tapi karena kehadiran mereka saja sudah cukup membuat hari terasa sedikit lebih menarik.</p>

      <p class='center-text'>Dan jujur saja, kamu adalah salah satu orang itu.</p>

      <div class='section-break'>· · · · ·</div>

      <p>Aku tidak tahu apakah kamu pernah menyadarinya atau tidak. Mungkin tidak. Bahkan kemungkinan besar memang tidak. Tapi setiap kali aku melihatmu, ada sesuatu yang membuatku berhenti sebentar dari apa yang sedang kupikirkan.</p>

      <p class='center-text no-indent'>Bukan karena sesuatu yang berlebihan.</p>
      <p class='center-text no-indent'>Hanya karena kamu.</p>

      <div class='section-break'>· · · · ·</div>

      <p>Kadang aku berpikir, aneh juga bagaimana seseorang bisa tiba-tiba menjadi penting dalam pikiran kita, padahal mungkin kita tidak terlalu sering berbicara. Dunia ini penuh dengan orang, penuh dengan wajah yang kita lihat setiap hari, tapi hanya sedikit yang benar-benar kita ingat.</p>

      <p class='center-text'>Dan entah kenapa, kamu termasuk yang selalu teringat.</p>

      <div class='section-break'>· · · · ·</div>

      <p>Aku tidak tahu harus menyebut ini sebagai apa. Mungkin sekadar kagum. Mungkin rasa suka yang sederhana. Atau mungkin hanya perasaan yang muncul tanpa alasan yang jelas.</p>

      <p>Yang aku tahu, namamu pernah terlintas di pikiranku lebih dari sekali.</p>

      <p class='center-text'>Bahkan mungkin lebih sering daripada yang seharusnya.</p>

      <div class='section-break'>· · · · ·</div>

      <p>Aku juga sadar bahwa hidup setiap orang berjalan dengan cara yang berbeda. Kita semua punya cerita masing-masing, punya rencana masing-masing, dan punya jalan yang belum tentu sama. Bisa saja suatu hari nanti kita benar-benar berjalan ke arah yang berbeda tanpa pernah menyadari kapan tepatnya kita berpisah arah.</p>

      <p class='center-text'>Itu hal yang sangat mungkin terjadi.</p>

      <div class='section-break'>· · · · ·</div>

      <p>Tapi sebelum waktu berjalan terlalu jauh, sebelum kenangan berubah menjadi sesuatu yang samar, aku ingin meninggalkan sesuatu yang sederhana: sebuah tulisan yang mengatakan bahwa pernah ada seseorang yang menganggapmu istimewa dengan caranya sendiri.</p>

      <p class='center-text no-indent'>Tanpa perlu kamu lakukan apa-apa.</p>
      <p class='center-text no-indent'>Tanpa perlu kamu sadari.</p>

      <div class='section-break'>· · · · ·</div>

      <p>Aku tidak berharap sesuatu yang besar dari tulisan ini. Tidak ada tuntutan, tidak ada harapan yang berat. Ini hanya sebuah cara untuk menyimpan satu perasaan kecil agar tidak hilang begitu saja.</p>

      <p>Karena kadang, yang paling berharga dari sebuah perasaan bukanlah apakah perasaan itu dibalas atau tidak.</p>

      <p class='center-text'>Melainkan fakta bahwa perasaan itu <em>pernah ada</em>.</p>

      <p>Dan aku tidak ingin pura-pura bahwa itu tidak pernah terjadi.</p>

      <div class='section-break'>· · · · ·</div>

      <p>Jika suatu hari nanti aku membuka kembali file ini, mungkin aku akan tersenyum sendiri dan mengingat masa di mana semuanya terasa sederhana. Masa di mana seseorang bisa menjadi alasan kecil untuk merasa senang dalam satu hari.</p>

      <p>Dan jika kebetulan suatu hari kamu benar-benar membaca ini, aku hanya ingin kamu tahu satu hal.</p>

      <p class='center-text' style='font-size:1.25rem; color: rgba(245,208,214,0.95); text-shadow: 0 0 20px rgba(232,160,168,0.4);'>
        Di antara miliaran orang di dunia ini, pernah ada seseorang yang menuliskan namamu dengan sangat hati-hati di sebuah notebook, hanya karena dia tidak ingin melupakannya.
      </p>

      <div class='section-break'>· · · · ·</div>

      <p class='center-text' style='font-size:1.55rem; font-family: Playfair Display, serif; font-style:italic; filter:drop-shadow(0 0 16px rgba(232,160,168,0.5));'>
        <span class='name-inline'>Nasha Putri Zaqirah.</span>
      </p>

      <p>Nama yang sederhana, tapi pernah menjadi bagian dari sebuah cerita kecil dalam hidup seseorang.</p>

      <p class='center-text no-indent'>Mungkin cerita itu tidak besar.</p>
      <p class='center-text no-indent'>Mungkin juga tidak penting bagi dunia.</p>

      <p>Tapi bagi orang yang menuliskannya, cerita itu cukup berarti untuk diabadikan.</p>

      <div class='section-break'>· · · · ·</div>

      <p>Dan mungkin, hanya mungkin, suatu hari nanti aku akan membuka file ini lagi dan tersenyum karena pernah mengenal seseorang sepertimu.</p>

      <p class='center-text' style='font-size:1.15rem; color: rgba(245,208,214,0.9); margin-top: 2em;'>
        Terima kasih sudah menjadi bagian kecil dari cerita itu.
      </p>

    </div>

    <!-- Closing -->
    <div class='letter-closing'>
      <span class='closing-dash'>— seseorang yang pernah diam-diam menyukai kamu</span>
    </div>

  </div>
"""))
# Out:
#   <!-- ══ LETTER ═══════════════════════════════════ -->
#   <div id='nasha-letter'>
#
#     <div class='floating-hearts' aria-hidden='true'>
#       <span class='fheart' style='left:8%;  animation-duration:8s;  animation-delay:0s;   font-size:0.75rem;'>♡</span>
#       <span class='fheart' style='left:22%; animation-duration:11s; animation-delay:2s;   font-size:0.55rem;'>♡</span>
#       <span class='fheart' style='left:42%; animation-duration:9s;  animation-delay:4s;   font-size:0.9rem; '>♡</span>
#       <span class='fheart' style='left:65%; animation-duration:13s; animation-delay:1.5s; font-size:0.6rem; '>♡</span>
#       <span class='fheart' style='left:80%; animation-duration:7s;  animation-delay:3s;   font-size:0.8rem; '>♡</span>
#       <span class='fheart' style='left:92%; animation-duration:10s; animation-delay:6s;   font-size:0.5rem; '>♡</span>
#     </div>
#
#     <p class='letter-salutation'>Untuk <span class='name-inline'>Nasha Putri Zaqirah</span>,</p>
#
# ...

# %%
from IPython.display import HTML, display

display(HTML("""
  <!-- ══ POEM ═════════════════════════════════════ -->
  <div id='nasha-poem'>
    <span class='poem-line'>ada nama yang tidak pernah benar-benar pergi</span>
    <span class='poem-line'>meski bibir tidak pernah mengucapkannya keras-keras</span>
    <span class='poem-gap'></span>
    <span class='poem-line'>tertulis di sini, di antara fungsi dan variabel,</span>
    <span class='poem-line'>seperti konstanta yang tidak berubah —</span>
    <span class='poem-gap'></span>
    <span class='poem-line' style='font-size:1.45rem; background: linear-gradient(135deg,#f5d0d6,#d4a96a); -webkit-background-clip:text; -webkit-text-fill-color:transparent; background-clip:text; filter:drop-shadow(0 0 10px rgba(232,160,168,0.5));'>
      Nasha Putri Zaqirah.
    </span>
  </div>

  <!-- ══ FOOTER ════════════════════════════════════ -->
  <div id='nasha-footer'>
    <div class='divider-ornament'>
      <span>✦ &nbsp; ♡ &nbsp; ✦</span>
    </div>
    <div class='footer-name'>Nasha Putri Zaqirah</div>
    <div class='footer-meta'>diabadikan dalam sebuah notebook &nbsp;·&nbsp; dengan sepenuh hati</div>
  </div>

</div><!-- /#nasha-main -->
"""))
# Out:
#   <!-- ══ POEM ═════════════════════════════════════ -->
#   <div id='nasha-poem'>
#     <span class='poem-line'>ada nama yang tidak pernah benar-benar pergi</span>
#     <span class='poem-line'>meski bibir tidak pernah mengucapkannya keras-keras</span>
#     <span class='poem-gap'></span>
#     <span class='poem-line'>tertulis di sini, di antara fungsi dan variabel,</span>
#     <span class='poem-line'>seperti konstanta yang tidak berubah —</span>
#     <span class='poem-gap'></span>
#     <span class='poem-line' style='font-size:1.45rem; background: linear-gradient(135deg,#f5d0d6,#d4a96a); -webkit-background-clip:text; -webkit-text-fill-color:transparent; background-clip:text; filter:drop-shadow(0 0 10px rgba(232,160,168,0.5));'>
#       Nasha Putri Zaqirah.
#     </span>
#   </div>
#
#   <!-- ══ FOOTER ════════════════════════════════════ -->
#   <div id='nasha-footer'>
#     <div class='divider-ornament'>
#       <span>✦ &nbsp; ♡ &nbsp; ✦</span>
#     </div>
# ...
